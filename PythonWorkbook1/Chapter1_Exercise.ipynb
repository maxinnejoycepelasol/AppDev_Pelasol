# %% [markdown]
# ###Chapter 1

# %% [markdown]
# ###Exercise 1
# Exercise 1 Each line of code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
print('Hello world!') #The error is because the letter P is in big letter it should be in small letter
# Out:
# Hello world!

# %%
print('Hello world!') #Put open parenthesis
# Out:
# Hello world!

# %%
print('Hello world!') #no quotation mark
# Out:
# Hello world!

# %%
print('Hello world!') #double quotation mark
# Out:
# Hello world!

# %% [markdown]
# ###Exercise 2
# Exercise 2 What is the output of the code below? [PEW]

# %%
x = 43
x = x + 1
print(x) #No error
# Out:
# 44

# %% [markdown]
# ###Exercise 3
# Exercise 3 The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = x + 1
print(x) #Change the variable X into small letter
